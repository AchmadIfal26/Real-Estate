# %% [markdown]
# # Import Library

# %%
# prompt: import pandas, numpy, seaborn, visualzation and machine learning

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline

# %% [markdown]
# # Import Data

# %%
estate = pd.read_csv('/content/real_estate.csv')
estate
# Out:
#       Date Recorded  List Year        Town            Address  Assessed Value  \
# 0        2021-04-14       2020     Ansonia      323 BEAVER ST        133000.0
# 1        2021-05-26       2020     Ansonia     152 JACKSON ST        110500.0
# 2        2021-09-13       2020     Ansonia    230 WAKELEE AVE        150500.0
# 3        2020-12-14       2020     Ansonia        57 PLATT ST        127400.0
# 4        2021-09-07       2020        Avon       245 NEW ROAD        217640.0
# ...             ...        ...         ...                ...             ...
# 20907    2021-08-25       2020  East Haven     68 BENJAMIN RD        202870.0
# 20908    2020-12-07       2020    Cornwall   FURNACE BROOK RD        504560.0
# 20909    2021-05-26       2020  Manchester  132 MOUNTAIN ROAD        208000.0
# 20910    2020-12-09       2020  Manchester  18 HILLCREST ROAD        154100.0
# 20911    2020-10-01       2020  Bridgeport                NaN             NaN
#
#        Sale Amount  Sales Ratio Property Type Residential Type  Longitude  \
# 0         248400.0       0.5354   Residential    Single Family  -73.06822
# 1         239900.0       0.4606   Residential     Three Family        NaN
# 2         325000.0       0.4630    Commercial              NaN        NaN
# 3         202500.0       0.6291   Residential       Two Family        NaN
# 4         400000.0       0.5441   Residential    Single Family        NaN
# ...            ...          ...           ...              ...        ...
# 20907     399900.0       0.5073   Residential    Single Family        NaN
# 20908     559800.0       0.9013   Vacant Land              NaN        NaN
# 20909     400000.0       0.5200   Residential    Single Family        NaN
# 20910     275000.0       0.5603   Residential    Single Family        NaN
# 20911          NaN          NaN           NaN              NaN        NaN
#
#        Latitude
# 0      41.35014
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# ...         ...
# 20907       NaN
# 20908       NaN
# 20909       NaN
# 20910       NaN
# 20911       NaN
#
# [20912 rows x 11 columns]

# %% [markdown]
# # Cleaning Data

# %%
estate.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20912 entries, 0 to 20911
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date Recorded     20912 non-null  object
#  1   List Year         20912 non-null  int64
#  2   Town              20912 non-null  object
#  3   Address           20911 non-null  object
#  4   Assessed Value    20911 non-null  float64
#  5   Sale Amount       20911 non-null  float64
#  6   Sales Ratio       20911 non-null  float64
#  7   Property Type     20825 non-null  object
#  8   Residential Type  18882 non-null  object
#  9   Longitude         9925 non-null   float64
#  10  Latitude          9925 non-null   float64
# dtypes: float64(5), int64(1), object(5)
# memory usage: 1.8+ MB

# %%
estate.describe()
# Out:
#           List Year  Assessed Value   Sale Amount   Sales Ratio    Longitude  \
# count  20912.000000    2.091100e+04  2.091100e+04  20911.000000  9925.000000
# mean    2019.922772    3.871547e+05  5.393917e+05      0.923444   -72.842730
# std        1.208902    2.085618e+06  1.333739e+06      7.296897     0.455315
# min     2001.000000    0.000000e+00  0.000000e+00      0.000000   -75.222600
# 25%     2020.000000    1.046500e+05  1.900000e+05      0.481800   -73.204450
# 50%     2020.000000    1.561000e+05  2.860000e+05      0.557600   -72.805810
# 75%     2020.000000    2.575750e+05  4.650000e+05      0.650100   -72.554860
# max     2020.000000    6.023185e+07  6.350000e+07    671.889400   -71.792590
#
#           Latitude
# count  9925.000000
# mean     41.540852
# std       0.266232
# min      38.330070
# 25%      41.345340
# 50%      41.605630
# 75%      41.761440
# max      42.036000

# %%
estate.isnull().sum()
# Out:
# Date Recorded           0
# List Year               0
# Town                    0
# Address                 1
# Assessed Value          1
# Sale Amount             1
# Sales Ratio             1
# Property Type          87
# Residential Type     2030
# Longitude           10987
# Latitude            10987
# dtype: int64

# %%
estate.duplicated().sum()
# Out:
# 61

# %%
estate.drop_duplicates(inplace=True)

# %%
estate.duplicated().sum()
# Out:
# 0

# %%
estate.isna().sum()
# Out:
# Date Recorded           0
# List Year               0
# Town                    0
# Address                 1
# Assessed Value          1
# Sale Amount             1
# Sales Ratio             1
# Property Type          87
# Residential Type     2025
# Longitude           10951
# Latitude            10951
# dtype: int64

# %%
estate.isnull().sum()
# Out:
# Date Recorded           0
# List Year               0
# Town                    0
# Address                 1
# Assessed Value          1
# Sale Amount             1
# Sales Ratio             1
# Property Type          87
# Residential Type     2025
# Longitude           10951
# Latitude            10951
# dtype: int64

# %%
print(estate.columns)
# Out:
# Index(['Date Recorded', 'List Year', 'Town', 'Address', 'Assessed Value',
#        'Sale Amount', 'Sales Ratio', 'Property Type', 'Residential Type',
#        'Longitude', 'Latitude'],
#       dtype='object')

# %%
estate['Date Recorded'].dropna(inplace=True)

# %%
estate['Address'] = estate['Address'].str.replace('Street', '')
estate['Address'] = estate['Address'].fillna('Unknown')
estate['Assessed Value'] = estate['Assessed Value'].fillna(estate['Assessed Value'].median())
estate['Residential Type'] = estate['Residential Type'].fillna('Unknown')
estate['Property Type'] = estate['Property Type'].fillna('Unknown')
estate['Longitude'] = estate['Longitude'].fillna('Unknown')
estate['Latitude'] = estate['Latitude'].fillna('Unknown')
estate['Date Recorded'] = estate['Date Recorded'].fillna('Unknown')

# %%
estate
# Out:
#       Date Recorded  List Year        Town            Address  Assessed Value  \
# 0        2021-04-14       2020     Ansonia      323 BEAVER ST        133000.0
# 1        2021-05-26       2020     Ansonia     152 JACKSON ST        110500.0
# 2        2021-09-13       2020     Ansonia    230 WAKELEE AVE        150500.0
# 3        2020-12-14       2020     Ansonia        57 PLATT ST        127400.0
# 4        2021-09-07       2020        Avon       245 NEW ROAD        217640.0
# ...             ...        ...         ...                ...             ...
# 20907    2021-08-25       2020  East Haven     68 BENJAMIN RD        202870.0
# 20908    2020-12-07       2020    Cornwall   FURNACE BROOK RD        504560.0
# 20909    2021-05-26       2020  Manchester  132 MOUNTAIN ROAD        208000.0
# 20910    2020-12-09       2020  Manchester  18 HILLCREST ROAD        154100.0
# 20911    2020-10-01       2020  Bridgeport            Unknown        156015.0
#
#        Sale Amount  Sales Ratio Property Type Residential Type Longitude  \
# 0         248400.0       0.5354   Residential    Single Family -73.06822
# 1         239900.0       0.4606   Residential     Three Family   Unknown
# 2         325000.0       0.4630    Commercial          Unknown   Unknown
# 3         202500.0       0.6291   Residential       Two Family   Unknown
# 4         400000.0       0.5441   Residential    Single Family   Unknown
# ...            ...          ...           ...              ...       ...
# 20907     399900.0       0.5073   Residential    Single Family   Unknown
# 20908     559800.0       0.9013   Vacant Land          Unknown   Unknown
# 20909     400000.0       0.5200   Residential    Single Family   Unknown
# 20910     275000.0       0.5603   Residential    Single Family   Unknown
# 20911          NaN          NaN       Unknown          Unknown   Unknown
#
#        Latitude
# 0      41.35014
# 1       Unknown
# 2       Unknown
# 3       Unknown
# 4       Unknown
# ...         ...
# 20907   Unknown
# 20908   Unknown
# 20909   Unknown
# 20910   Unknown
# 20911   Unknown
#
# [20851 rows x 11 columns]

# %%
estate.isna().sum()
# Out:
# Date Recorded       0
# List Year           0
# Town                0
# Address             0
# Assessed Value      0
# Sale Amount         1
# Sales Ratio         1
# Property Type       0
# Residential Type    0
# Longitude           0
# Latitude            0
# dtype: int64

# %%
estate.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20851 entries, 0 to 20911
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date Recorded     20851 non-null  object
#  1   List Year         20851 non-null  int64
#  2   Town              20851 non-null  object
#  3   Address           20851 non-null  object
#  4   Assessed Value    20851 non-null  float64
#  5   Sale Amount       20850 non-null  float64
#  6   Sales Ratio       20850 non-null  float64
#  7   Property Type     20851 non-null  object
#  8   Residential Type  20851 non-null  object
#  9   Longitude         20851 non-null  object
#  10  Latitude          20851 non-null  object
# dtypes: float64(3), int64(1), object(7)
# memory usage: 2.4+ MB

# %% [markdown]
# # Feature Engineering and Dimensional Reduction

# %%
property_type_counts = estate['Property Type'].value_counts()
print(property_type_counts)
# Out:
# Property Type
# Residential       18826
# Vacant Land        1045
# Commercial          641
# Apartments          171
# Unknown              87
# Industrial           79
# Public Utility        2
# Name: count, dtype: int64

# %%
# prompt: Tahun berapa rata-rata harga jual properti tertinggi? (Year, Sale Amount)

highest_sale_amount_by_year = estate.groupby('Date Recorded')['Sale Amount'].mean().sort_values(ascending=False).head(1)
year_with_highest_sale_amount = highest_sale_amount_by_year.index[0]
print(f"Year with highest average sale amount: {year_with_highest_sale_amount}")
# Out:
# Year with highest average sale amount: 2021-04-24

# %%
estate = pd.DataFrame(estate)

# Simpan DataFrame ke CSV
estate.to_csv('Estate Fix.csv', index=False)
